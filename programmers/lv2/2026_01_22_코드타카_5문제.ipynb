# %% [markdown]
# # Programmers Level 2 (2026-01-22, 3 problems)
# ## 문제 리스트
# | No | 문제 | 날짜 | 언어 | 링크 |
# |----|------|------|------|------|
# | 34 | 문자열 내림차순으로 배치하기 | 2026-01-22  | Python |[🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12917)|
# | 35 | 부족한 금액 계산하기 | 2026-01-22 | Python |[🔗](https://school.programmers.co.kr/learn/courses/30/lessons/82612)|
# | 36 | 문자열 다루기 기본 | 2026-01-22 | Python |[🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12918)|

# %% [markdown]
# ## 34번 문제: 문자열 내림차순으로 배치하기  [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12917)
# 풀이
# ```python
# def solution(s):
#     return ''.join(sorted(s, reverse=True))
# ```
#
# ### 문제 풀이 과정에서의 생각
# 들어오는 값을 리스트로 받아서 sort, reverse를 해 역순으로 정렬. 이후 다시 문자열로 변환
#
# <br>
#
# ### 막혔던 부분과 해결 방법
# 문자열로 변환하는 방법이 기억이 안나서 검색.<br>
# 구분자.join(리스트): 리스트에 들어있는 문자열들을 하나의 문자열로 이어 붙인다 일종의 문자열 +<br>
# 를 알게 되어서 사용

# %% [markdown]
# ## 35번 문제:  부족한 금액 계산하기 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/82612)
# 풀이
# ```python
# def solution(price, money, count):
#     fare = 0
#     for i in range(1, count + 1):
#         fare += price*i
#     if fare - money > 0:
#         return fare - money
#     else:
#         return 0
# ```
#
# ### 문제 풀이 과정에서의 생각
# 반복문을 이용해 총합 요금을 구한뒤 (price에 1~count회까지 곱한값을 전부 더함)<br>
# 조건문으로 금액이 부족하면 부족한 만큼, 안 부족하면 0을 반환

# %% [markdown]
# ## 36번 문제: 문자열 다루기 기본 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12918)
# 풀이
# ```python
# def solution(s):
#     if len(s) not in (4, 6):
#         return False
#     try:
#         int(s)
#         return True
#     except ValueError:
#         return False
# ```
#
# ### 문제 풀이 과정에서의 생각
# 조건문을 문자열이 4~6으로 필터링<br>
# try/except를 이용해 받은 값을 int로 바꾸었을때 에러가 나면 문자열 안에 문자가 들어가있는 것이기 때문에 False 반환(try/except로 인해 오류가 발생하지 않음)
