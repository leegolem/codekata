# %% [markdown]
# # Programmers Level 1 (2026-01-11, 5 problems)
# ## 문제 리스트
# | No | 문제 | 날짜 | 언어 | 링크 |
# |----|------|------|------|------|
# | 6 | 두 수의 합 구하기| 2026-01-11 | Python | [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120802) |
# | 7 | 두 수의 나눗셈| 2026-01-11 | Python | [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120806) |
# | 8 | 각도기        | 2026-01-11 | Python | [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120829) |
# | 9 | 짝수의 합     | 2026-01-11 | Python | [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120831) |
# | 10 | 배열의 평균값 | 2026-01-11 | Python | [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120817) |

# %% [markdown]
# ## 6번 문제: 두 수의 합 구하기 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120802)
#
# ```python
# def solution(num1, num2):
#     answer = num1+num2
#     return answer
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# ```

# %% [markdown]
# ## 7번 문제: 두 수의 나눗셈  [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120806)
# 풀이
# ```python
# def solution(num1, num2):
#     answer = int((num1 / num2)*1000)
#     return answer
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# ```

# %% [markdown]
# ## 8번 문제: 각도기  [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120829)
# 풀이
# ```python
# def solution(angle):
#     if 0<angle<90:
#         return 1
#     elif angle == 90:
#         return 2
#     elif 90<angle<180:
#         return 3
#     elif angle == 180:
#         return 4
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# def solution(angle):
#     if angle == 180:
#         return 4
#     elif angle > 90:
#         return 3
#     elif angle == 90:
#         return 2
#     elif angle < 90:
#         return 1
# ```
# 다른점: 첫번째 코드는 낮은값부터 위로, 다른풀이는 높은값에서 낮은 값으로 내려가며 코드 진행

# %% [markdown]
# ## 9번 문제: 짝수의 합 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120831)
# 풀이
# ```python
# def solution(n):
#     num = 0
#     for i in range(0, n + 1, 2):
#         num += i
#     return num
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# def solution(n):
#     return sum(i for i in range(0, n + 1, 2))
# ```
# 다른점: 컴프리헨션을 사용해 코드줄을 단축함

# %% [markdown]
# ## 10번 문제: 배열의 평균값 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120817)
# 풀이
# ```python
# def solution(numbers):
#     avg = sum(numbers) / len(numbers)
#     return avg
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# ```
