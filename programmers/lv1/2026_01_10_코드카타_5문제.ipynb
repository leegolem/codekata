# %% [markdown]
# # Programmers Level 1 (2026-01-11, 5 problems)
#
# # 문제 리스트
# | No | 문제 | 날짜 | 언어 | 링크 |
# |----|------|------|------|------|
# | 1 | 두 수의 차 | 2026-01-10 | Python | [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120803) |
# | 2 | 두 수의 곱 | 2026-01-10 | Python | [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120804) |
# | 3 | 몫 구하기 | 2026-01-10 | Python | [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120805) |
# | 4 | 나이 출력 | 2026-01-10 | Python | [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120820) |
# | 5 | 숫자 비교하기 | 2026-01-10 | Python | [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120807) |

# %% [markdown]
# ## 1 번 문제: 두 수의 차 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120803)
#
# 풀이
# ```python
# def solution(num1, num2):
#     answer = num1 - num2
#     return answer
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# ```

# %% [markdown]
# ## 2 번 문제: 두 수의 곱  [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120804)
#
# 풀이
# ```python
# def solution(num1, num2):
#     answer = num1 * num2
#     return answer
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# ```

# %% [markdown]
# ## 3 번 문제: 몫 구하기 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120805)
#
# 풀이
# ```python
# def solution(num1, num2):
#     answer = num1 // num2
#     return answer
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# ```

# %% [markdown]
# ## 4 번 문제: 나이 출력 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120820)
#
# 풀이
# ```python
# def solution(age):
#     answer = 2022 - age+1
#     return answer
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# ```

# %% [markdown]
# ## 5 번 문제: 숫자 비교하기 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/120807)
#
# 풀이
# ```python
#
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# def solution(num1, num2):
#     if num1 == num2:
#         return 1
#     elif num1 != num2:
#         return -1
# ```
