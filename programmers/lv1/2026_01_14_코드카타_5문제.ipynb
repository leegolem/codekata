# %% [markdown]
# # Programmers Level 1 (2026-01-14, 5 problems)
# ## 문제 리스트
# | No | 문제 | 날짜 | 언어 | 링크 |
# |----|------|------|------|------|
# | 21 | 햐사드 수 | 2026-01-14 | Python |[🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12947)|
# | 22 | 두 정수 사이의 합 | 2026-01-14 | Python |[🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12912)|
# | 23 | 콜라츠 추측 | 2026-01-14 | Python |[🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12943)|
# | 24 | 서울에서 김서방 찾기 | 2026-01-14 | Python |[🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12919)|
# | 25 | 나누어 떨어지는 숫자 배열  | 2026-01-14 | Python |[🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12910)|

# %% [markdown]
# ## 21번 문제: 하샤드 수 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12947)
# 풀이
# ```python
# def solution(x):
#     harshad_num = 0
#     n = x
#
#     while n > 0:                # 매개변수의 자리수를 모두 더하면 종료
#         harshad_num += n % 10   # 매개변수의 자리수 더함
#         n //= 10                # 매개변수의 다음 자리수로 바꿈
#
#     return x % harshad_num == 0 # 자릿수의 합이 매개변수로 나눠 떨어지면 하샤드
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# ```

# %% [markdown]
# ## 22번 문제: 두 정수 사이의 합 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12912)
# 풀이
# ```python
# def solution(a, b):
#     answer = 0
#     if a > b:
#         a, b = b, a
#
#     for i in range(a,b+1):
#         answer += i
#     return answer
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# def solution(a, b):
#     answer = 0
#     if a > b:
#         a, b = b, a
#
#     count= b - a + 1
#     return (a + b) * count // 2
# ```
# 등차수열 공식으로 문제 풀이

# %% [markdown]
# ## 23번 문제: 콜라츠 추측 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12943)
# 풀이
# ```python
# def solution(num):
#
#     for i in range(500):
#         if num == 1:
#             return i
#
#         if num % 2 == 0:
#             num //= 2
#         else:
#             num = num * 3 + 1
#
#     return -1
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# ```

# %% [markdown]
# ## 24번 문제: 서울에서 김서방 찾기 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12919)
# 풀이
# ```python
# def solution(seoul):
#     for i in range(len(seoul)):
#         if seoul[i] == "Kim":
#             return f"김서방은 {i}에 있다"
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# ```

# %% [markdown]
# ## 25번 문제: 나누어 떨어지는 숫자 배열 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12910)
# 풀이
# ```python
# def solution(arr, divisor):
#     answer = []
#     for num in arr:
#         if num % divisor == 0:
#             answer.append(num)
#
#     if not answer:
#         return [-1]
#
#     answer.sort()
#     return answer
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# ```
