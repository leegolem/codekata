# %% [markdown]
# # Programmers Level 1 (2026-01-16, 5 problems)
# ## 문제 리스트
# | No | 문제 | 날짜 | 언어 | 링크 |
# |----|------|------|------|------|
# | 26 | 음양 더하기 | 2026-01-16 | Python |[🔗](https://school.programmers.co.kr/learn/courses/30/lessons/76501)|
# | 27 | 핸드폰 번호 가리기 | 2026-01-16 | Python |[🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12948)|
# | 28 | 없는 숫자 더하기 | 2026-01-16 | Python |[🔗](https://school.programmers.co.kr/learn/courses/30/lessons/86051)|
# | 29 | 제일 작은 수 구하기 | 2026-01-16 | Python |[🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12935)|
# | 30 | 가운데 글자 가져오기 | 2026-01-16 | Python |[🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12903)|

# %% [markdown]
# ## 26번 문제:음양 더하기  [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/76501)
# 풀이
# ```python
# def solution(absolutes, signs):
#     answer = 0
#     for i in range(len(absolutes)):
#         if signs[i]:
#             answer += absolutes[i]
#         else:
#             answer -= absolutes[i]
#     return answer
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# def solution2(absolutes, signs):
#     answer = 0
#     for i in range(len(absolutes)):
#         answer += absolutes[i] if signs[i] else -absolutes[i]
#     return answer
# ```
# 삼항 연산자를 사용해서 문제 풀이 컴프리헨션으로 나중에 한번 더 풀어복;

# %% [markdown]
# ## 27번 문제: 핸드폰 번호 가리기 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12948)
# 풀이
# ```python
# def solution(phone_number):
#     long = len(phone_number[:-4])
#     answer = ("*" * long) + phone_number[-4:]
#     return answer
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# ```

# %% [markdown]
# ## 28번 문제: 없는 숫자 더하기 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/86051)
# 풀이
# ```python
# def solution(numbers):
#     answer = 0
#
#     for i in range(10):
#         if i not in numbers:
#             answer += i
#
#     return answer
#
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# ```

# %% [markdown]
# ## 29번 문제: 제일 작은 수 구하기  [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12935)
# 풀이
# ```python
# def solution(arr):
#     if len(arr) == 1:
#         return [-1]
#
#     arr.remove(min(arr))
#     return arr
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# ```

# %% [markdown]
# ## 30번 문제: 가운데 글자 가져오기 [🔗](https://school.programmers.co.kr/learn/courses/30/lessons/12903)
# 풀이
# ```python
# def solution(s):
#     length = len(s)
#     mid = length // 2
#
#     if length % 2 == 1:
#         return s[mid]
#
#     return s[mid-1:mid+1]
# ```
#
# ### 문제 풀이 과정에서의 생각
#
# ### 막혔던 부분과 해결 방법
#
# ### 다른 풀이 방식 또는 개선된 풀이
# ```python
# ```
